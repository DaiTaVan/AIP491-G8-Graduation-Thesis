# %%
import pandas as pd
import json
from tqdm import tqdm
from rag_pipeline.llm import OpenAI

# %%
gpt_engine = OpenAI(api_key="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",
                    model_name='gpt-4o', 
                    temperature=0.2)

# %%
# Sample
gpt_engine.generate('1+1=')
# Out:
# '1 + 1 = 2'

# %% [markdown]
# ### 1.1

# %%
df = pd.read_excel('dataset/summary benchmark.xlsx', sheet_name= '1-1 test')

# %%
standard_dict = list(df.T.to_dict().values())
standard_dict
# Out:
# [{'instruction': 'Để trả lời các câu hỏi sau, chỉ cần đưa thẳng nội dung luật. Sau đây là ví dụ:\nNội dung Điều 38 Bộ Luật Lao động là gì?\nTrả lời: Mỗi bên đều có quyền hủy bỏ việc đơn phương chấm dứt hợp đồng lao động trước khi hết thời hạn báo trước nhưng phải thông báo bằng văn bản và phải được bên kia đồng ý.\nXin vui lòng trả lời: ',
#   'question': 'Nội dung Điều 41 của Bộ luật lao động về nghĩa vụ của\n người sử dụng lao động khi đơn phương chấm dứt hợp đồng lao động trái pháp luật là gì?',
# ...

# %%
with open('benchmark_v2/1-1.json', 'w') as f1:
    json.dump(standard_dict, f1, indent=4, ensure_ascii=False)

# %%
standard_dict_with_answer = standard_dict.copy()

for ix, element in tqdm(enumerate(standard_dict_with_answer)):
    query = f"{element['instruction']}\n{element['question']}"
    chatgpt_answer = gpt_engine.generate(query)
    standard_dict_with_answer[ix]['prediction'] = chatgpt_answer

with open('benchmark_output/chatgpt/1-1.json', 'w') as f1:
    json.dump(standard_dict_with_answer, f1, indent=4, ensure_ascii=False)
# Out:
# 70it [01:38,  1.41s/it]

# %% [markdown]
# ### 1-2

# %%
df = pd.read_excel('dataset/summary benchmark.xlsx', sheet_name= '1-2 test')

# %%
standard_dict = list(df.T.to_dict().values())
standard_dict
# Out:
# [{'instruction': 'Hãy vận dụng kiến thức pháp luật của bạn để chọn câu trả lời đúng trong số A, B, C, D và viết nó vào sau [Câu trả lời đúng]. \nVí dụ: [Câu trả lời đúng] A. \nVui lòng câu trả lời đúng theo định dạng này. \nSau đây là ví dụ:\nCâu hỏi: Hiến pháp năm 2013 quy định Quốc ca nước Cộng hòa xã hội chủ nghĩa Việt Nam là nhạc và lời của bài:\nA: Quốc gia có cảng\nB: Quốc gia ký kết\nC: Quốc gia quần đảo; \nTrả lời: [Câu trả lời đúng] A.',
#   'question': 'Câu hỏi: Người chưa thành niên từ đủ mười lăm tuổi đến \nchưa đủ mười tám tuổi phạm tội thì hình phạt cao\n nhất có thể áp dụng là bao nhiêu năm tù? \nA. Không quá 5 năm tù. \nB. Không quá 10 năm tù. \nC. Không quá 18 năm tù. \nD. Không quá 15 năm tù.',
#   'answer': '[Câu trả lời đúng]D'},
# ...

# %%
with open('benchmark_v2/1-2.json', 'w') as f1:
    json.dump(standard_dict, f1, indent=4, ensure_ascii=False)

# %%
standard_dict_with_answer = standard_dict.copy()

for ix, element in tqdm(enumerate(standard_dict_with_answer)):
    query = f"{element['instruction']}\n{element['question']}"
    chatgpt_answer = gpt_engine.generate(query)
    standard_dict_with_answer[ix]['prediction'] = chatgpt_answer

with open('benchmark_output/chatgpt/1-2.json', 'w') as f1:
    json.dump(standard_dict_with_answer, f1, indent=4, ensure_ascii=False)
# Out:
# 70it [00:55,  1.26it/s]

# %% [markdown]
# ### 2-1

# %%
df = pd.read_excel('dataset/summary benchmark.xlsx', sheet_name= '2-1 test')

# %%
standard_dict = list(df.T.to_dict().values())
standard_dict
# Out:
# [{'instruction': 'Sửa lỗi chính tả, thừa, xóa, mất trật tự từ trong các câu văn bản pháp luật sau đây, hạn chế tối đa việc sửa đổi câu gốc, giữ nguyên ngữ nghĩa của câu gốc. Chỉ cần đưa ra những câu sửa đổi, hãy tuân thủ trả lời theo dạng này. Đây là một ví dụ:\nCục quản lý giao thông đã xác định rằng Hiệp hội H chịu trách nhiệm chính về vụ tai nạn \nTrả lời: Sở quản lý giao thông đã xác định rằng Hiệp hội H chịu trách nhiệm chính về vụ tai nạn. ',
#   'question': '\nCơ quan Công an, Viện kiểm sát nhân dân, Tòa án nhân dân và các cơ quan hữu quan khác có trách nhiệm thực hiện đầy đủ chức năng, nhiệm vụ, quyền hạn của mình, đồng thời  dẫn, giúp đỡ các cơ quan khác của Nhướnghà nước, tổ chức, cá nhân phòng ngừa và đấu tranh chống tội phạm, giám sát và giáo dục người phạm tội tại cộng đồng. ',
# ...

# %%
with open('benchmark_v2/2-1.json', 'w') as f1:
    json.dump(standard_dict, f1, indent=4, ensure_ascii=False)

# %%
standard_dict_with_answer = standard_dict.copy()

for ix, element in tqdm(enumerate(standard_dict_with_answer)):
    query = f"{element['instruction']}\n{element['question']}"
    chatgpt_answer = gpt_engine.generate(query)
    standard_dict_with_answer[ix]['prediction'] = chatgpt_answer

with open('benchmark_output/chatgpt/2-1.json', 'w') as f1:
    json.dump(standard_dict_with_answer, f1, indent=4, ensure_ascii=False)
# Out:
# 70it [01:49,  1.57s/it]

# %% [markdown]
# ### 2-2

# %%
df = pd.read_excel('dataset/summary benchmark.xlsx', sheet_name= '2-2 reset')

# %%
standard_dict = list(df.T.to_dict().values())
standard_dict
# Out:
# [{'instruction': 'Xác định loại trọng tâm tranh chấp có trong đoạn văn bản. Các loại tranh chấp bao gồm: Tranh chấp đất đai,Tranh chấp quyền sử dụng đất, Tranh chấp hợp đồng , Tranh chấp về xây dựng, Tranh chấp về thừa kế tài sản, Tranh chấp về quyền sở hữu và các quyền khác đối với tài sản.   Mỗi câu chỉ chứa một loại trọng tâm tranh chấp. ',
# ...

# %%
for ix in range(len(standard_dict)):
    for key, value in standard_dict[ix].items():
        standard_dict[ix][key] = value.strip().rstrip()

standard_dict
# Out:
# [{'instruction': 'Xác định loại trọng tâm tranh chấp có trong đoạn văn bản. Các loại tranh chấp bao gồm: Tranh chấp đất đai,Tranh chấp quyền sử dụng đất, Tranh chấp hợp đồng , Tranh chấp về xây dựng, Tranh chấp về thừa kế tài sản, Tranh chấp về quyền sở hữu và các quyền khác đối với tài sản.   Mỗi câu chỉ chứa một loại trọng tâm tranh chấp.',
# ...

# %%
with open('benchmark_v2/2-2.json', 'w') as f1:
    json.dump(standard_dict, f1, indent=4, ensure_ascii=False)

# %%
standard_dict_with_answer = standard_dict.copy()

for ix, element in tqdm(enumerate(standard_dict_with_answer)):
    query = f"{element['instruction']}\n{element['question']}"
    chatgpt_answer = gpt_engine.generate(query)
    standard_dict_with_answer[ix]['prediction'] = chatgpt_answer

with open('benchmark_output/chatgpt/2-2.json', 'w') as f1:
    json.dump(standard_dict_with_answer, f1, indent=4, ensure_ascii=False)
# Out:
# 90it [03:22,  2.25s/it]

# %% [markdown]
# ### 2-3

# %%
df = pd.read_excel('dataset/summary benchmark.xlsx', sheet_name= '2-3 test')

# %%
standard_dict = list(df.T.to_dict().values())
standard_dict
# Out:
# [{'instruction': "Xác định loại tranh chấp khi ly hôn được nhắc tới trong đoạn viết. Các loại tranh chấp bao gồm: Ly hôn và tranh chấp về nuôi con khi ly hôn', 'Ly hôn và tranh chấp chia tài sản khi ly hôn', 'Ly hôn và chia tài sản sau khi ly hôn', 'Tranh chấp về chia tài sản chung của vợ chồng trong thời kỳ hôn nhân', 'Tranh chấp tài sản trước hôn nhân', 'Tranh chấp về thay đổi người trực tiếp nuôi con sau khi ly hôn.', 'Tranh chấp về xác định cha, mẹ cho con hoặc xác định con cho cha, mẹ',  'Tranh chấp về cấp dưỡng', 'Tranh chấp về sinh con bằng kỹ thuật hỗ trợ sinh sản, mang thai hộ vì mục đích nhân đạo',  'Tranh chấp về nuôi con của nam, nữ chung sống với nhau như vợ chồng mà không đăng ký kết hôn hoặc khi hủy kết hôn trái pháp luật', 'Tranh chấp về chia tài sản của nam, nữ chung sống với nhau như vợ chồng mà không đăng ký kết hôn hoặc khi hủy kết hôn trái pháp luật', 'Các tranh chấp khác về hôn nhân và gia đình, trừ trường hợp thuộc thẩm quyền giải quyết của cơ quan, tổ chức khá
# ...

# %%
for ix in range(len(standard_dict)):
    for key, value in standard_dict[ix].items():
        standard_dict[ix][key] = value.strip().rstrip()

standard_dict
# Out:
# [{'instruction': "Xác định loại tranh chấp khi ly hôn được nhắc tới trong đoạn viết. Các loại tranh chấp bao gồm: Ly hôn và tranh chấp về nuôi con khi ly hôn', 'Ly hôn và tranh chấp chia tài sản khi ly hôn', 'Ly hôn và chia tài sản sau khi ly hôn', 'Tranh chấp về chia tài sản chung của vợ chồng trong thời kỳ hôn nhân', 'Tranh chấp tài sản trước hôn nhân', 'Tranh chấp về thay đổi người trực tiếp nuôi con sau khi ly hôn.', 'Tranh chấp về xác định cha, mẹ cho con hoặc xác định con cho cha, mẹ',  'Tranh chấp về cấp dưỡng', 'Tranh chấp về sinh con bằng kỹ thuật hỗ trợ sinh sản, mang thai hộ vì mục đích nhân đạo',  'Tranh chấp về nuôi con của nam, nữ chung sống với nhau như vợ chồng mà không đăng ký kết hôn hoặc khi hủy kết hôn trái pháp luật', 'Tranh chấp về chia tài sản của nam, nữ chung sống với nhau như vợ chồng mà không đăng ký kết hôn hoặc khi hủy kết hôn trái pháp luật', 'Các tranh chấp khác về hôn nhân và gia đình, trừ trường hợp thuộc thẩm quyền giải quyết của cơ quan, tổ chức khá
# ...

# %%
with open('benchmark_v2/2-3.json', 'w') as f1:
    json.dump(standard_dict, f1, indent=4, ensure_ascii=False)

# %%
standard_dict_with_answer = standard_dict.copy()

for ix, element in tqdm(enumerate(standard_dict_with_answer)):
    query = f"{element['instruction']}\n{element['question']}"
    chatgpt_answer = gpt_engine.generate(query)
    standard_dict_with_answer[ix]['prediction'] = chatgpt_answer

with open('benchmark_output/chatgpt/2-3.json', 'w') as f1:
    json.dump(standard_dict_with_answer, f1, indent=4, ensure_ascii=False)
# Out:
# 70it [01:23,  1.20s/it]

# %% [markdown]
# ### 2-4

# %%
df = pd.read_excel('dataset/summary benchmark.xlsx', sheet_name= '2-4 test')

# %%
standard_dict = list(df.T.to_dict().values())
standard_dict
# Out:
# [{'instruction': 'Xác định các loại tư vấn sau. Mỗi tư vấn chỉ thuộc một loại. Các loại bao gồm: Thuế, Lao động, An toàn lao động, Bảo hiểm xã hội, Bảo hiểm thất nghiệp, Đầu tư, Thương mại, Doanh nghiệp, Kế toán, Sở hữu trí tuệ, Đất đai - Nhà ở, Hôn nhân Gia đình, Dân sự, Hình sự, Bảo vệ môi trường, Phòng cháy chữa cháy, Tư pháp, Đấu thầu, Xây dựng , Tài chính ngân hàng, Bảo hiểm y tế , Kinh doanh bất động sản , Hóa chất\nViết câu trả lời giữa [thể loại] và , ví dụ: [thể loại] Hôn nhân và Gia đình . Vui lòng trả lời theo đúng định dạng này.\nĐây là một ví dụ:\nTư vấn: Trong một vụ tai nạn giao thông, công ty bảo hiểm và tài xế gây ra tai nạn đều phớt lờ. Những người bị thương đã được đưa đến bệnh viện và các thành viên trong gia đình đã tự mình điều trị cho họ. Luật sư nên xử lý như thế nào?\nTrả lời: [thể loại] hôn nhân và gia đình Vui lòng trả lời:',
# ...

# %%
for ix in range(len(standard_dict)):
    for key, value in standard_dict[ix].items():
        standard_dict[ix][key] = value.strip().rstrip()

standard_dict
# Out:
# [{'instruction': 'Xác định các loại tư vấn sau. Mỗi tư vấn chỉ thuộc một loại. Các loại bao gồm: Thuế, Lao động, An toàn lao động, Bảo hiểm xã hội, Bảo hiểm thất nghiệp, Đầu tư, Thương mại, Doanh nghiệp, Kế toán, Sở hữu trí tuệ, Đất đai - Nhà ở, Hôn nhân Gia đình, Dân sự, Hình sự, Bảo vệ môi trường, Phòng cháy chữa cháy, Tư pháp, Đấu thầu, Xây dựng , Tài chính ngân hàng, Bảo hiểm y tế , Kinh doanh bất động sản , Hóa chất\nViết câu trả lời giữa [thể loại] và , ví dụ: [thể loại] Hôn nhân và Gia đình . Vui lòng trả lời theo đúng định dạng này.\nĐây là một ví dụ:\nTư vấn: Trong một vụ tai nạn giao thông, công ty bảo hiểm và tài xế gây ra tai nạn đều phớt lờ. Những người bị thương đã được đưa đến bệnh viện và các thành viên trong gia đình đã tự mình điều trị cho họ. Luật sư nên xử lý như thế nào?\nTrả lời: [thể loại] hôn nhân và gia đình Vui lòng trả lời:',
# ...

# %%
with open('benchmark_v2/2-4.json', 'w') as f1:
    json.dump(standard_dict, f1, indent=4, ensure_ascii=False)

# %%
standard_dict_with_answer = standard_dict.copy()

for ix, element in tqdm(enumerate(standard_dict_with_answer)):
    query = f"{element['instruction']}\n{element['question']}"
    chatgpt_answer = gpt_engine.generate(query)
    standard_dict_with_answer[ix]['prediction'] = chatgpt_answer

with open('benchmark_output/chatgpt/2-4.json', 'w') as f1:
    json.dump(standard_dict_with_answer, f1, indent=4, ensure_ascii=False)
# Out:
# 70it [00:55,  1.26it/s]

# %% [markdown]
# ### 2-5

# %%
df = pd.read_excel('dataset/summary benchmark.xlsx', sheet_name= '2-5 test')

# %%
standard_dict = list(df.T.to_dict().values())
for ix in range(len(standard_dict)):
    for key, value in standard_dict[ix].items():
        standard_dict[ix][key] = value.strip().rstrip()

standard_dict
# Out:
# [{'instruction': 'Hướng dẫn: "Hãy đọc hiểu văn bản được cung cấp và trích xuất ra các thông tin trong văn bản để trả lời câu hỏi. Dưới đây là một ví dụ: \nVào ngày 27/02/2024, tại một phòng trọ ở thị xã D, tỉnh Hà Nam, bị cáo Đinh Việt H (22 tuổi) đã xảy ra mâu thuẫn với vợ mình là chị Bùi Thị Phương T trong lúc ăn uống cùng bạn bè. Sau khi xảy ra tranh cãi về tiền bạc, H đã dùng dao phay chém vào đầu và tay trái của chị T, gây thương tích 11% sức khỏe. Sau đó, H còn đập vỡ điện thoại của chị T. Chị T được đưa đi cấp cứu kịp thời nên không thiệt mạng. Bị cáo H bị truy tố về tội "Giết người" và "Hủy hoại tài sản."\n\nCâu hỏi khai thác: Nguyên nhân dẫn đến mâu thuẫn giữa bị cáo và nạn nhân là gì?\nTrả lời: Nguyên nhân dẫn đến mâu thuẫn giữa bị cáo Đinh Việt H và nạn nhân Bùi Thị Phương T xuất phát từ việc chị T đưa tiền thừa sau khi đi chợ cho H. H cảm thấy vợ tỏ thái độ khi đưa tiền, dẫn đến hành vi bạo lực.\nHãy trả lời câu hỏi sau:',
# ...

# %%
with open('benchmark_v2/2-5.json', 'w') as f1:
    json.dump(standard_dict, f1, indent=4, ensure_ascii=False)

# %%
standard_dict_with_answer = standard_dict.copy()

for ix, element in tqdm(enumerate(standard_dict_with_answer)):
    query = f"{element['instruction']}\n{element['question']}"
    chatgpt_answer = gpt_engine.generate(query)
    standard_dict_with_answer[ix]['prediction'] = chatgpt_answer

with open('benchmark_output/chatgpt/2-5.json', 'w') as f1:
    json.dump(standard_dict_with_answer, f1, indent=4, ensure_ascii=False)
# Out:
# 70it [01:52,  1.61s/it]

# %% [markdown]
# ### 2-6

# %%
df = pd.read_excel('dataset/summary benchmark.xlsx', sheet_name= '2-6 test')

# %%
standard_dict = list(df.T.to_dict().values())
for ix in range(len(standard_dict)):
    for key, value in standard_dict[ix].items():
        standard_dict[ix][key] = value.strip().rstrip()

standard_dict
# Out:
# [{'instruction': 'Dựa vào đoạn văn bản đã cho, trích xuất thông tin thực thể từ câu. Các loại thực thể bao gồm: Nghi phạm, Nạn nhân, Tài sản bị đánh cắp, Công cụ gây án, Thời gian, Địa điểm, Tổ chức pháp lý, Tội danh, Phán quyết. Liệt kê từng thông tin thực thể. Dưới đây là một ví dụ: \nCâu: Sau đó, Nguyễn Đình N đã dùng số tiền 200 đồng thu được từ việc đánh cắp để bị tiêu hết. \nNghi phạm: Nguyễn Đình N\nTài sản từ bị đánh cắp: 200 đồng \nXin bạn trả lời:',
#   'question': 'Sau khi phá án, cơ quan công an đã thu hồi điện thoại và trả lại cho các nạn nhân là ông/bà Hiếu và Ngân theo đúng quy định của pháp luật.',
#   'answer': 'Nạn nhân: Hiếu, Ngân \nTài sản bị đánh cắp: điện thoại đã thu hồi\nTổ chức: cơ quan công an'},
# ...

# %%
with open('benchmark_v2/2-6.json', 'w') as f1:
    json.dump(standard_dict, f1, indent=4, ensure_ascii=False)

# %%
standard_dict_with_answer = standard_dict.copy()

for ix, element in tqdm(enumerate(standard_dict_with_answer)):
    query = f"{element['instruction']}\n{element['question']}"
    chatgpt_answer = gpt_engine.generate(query)
    standard_dict_with_answer[ix]['prediction'] = chatgpt_answer

with open('benchmark_output/chatgpt/2-6.json', 'w') as f1:
    json.dump(standard_dict_with_answer, f1, indent=4, ensure_ascii=False)
# Out:
# 70it [02:08,  1.84s/it]

# %% [markdown]
# ### 2-7

# %%
df = pd.read_excel('dataset/summary benchmark.xlsx', sheet_name= '2-7 test')

# %%
standard_dict = list(df.T.to_dict().values())
for ix in range(len(standard_dict)):
    for key, value in standard_dict[ix].items():
        standard_dict[ix][key] = value.strip().rstrip()

standard_dict
# Out:
# [{'instruction': 'Sau đây là một bản tin. Vui lòng tóm tắt báo cáo này bằng một vài câu.',
# ...

# %%
with open('benchmark_v2/2-7.json', 'w') as f1:
    json.dump(standard_dict, f1, indent=4, ensure_ascii=False)

# %%
standard_dict_with_answer = standard_dict.copy()

for ix, element in tqdm(enumerate(standard_dict_with_answer)):
    query = f"{element['instruction']}\n{element['question']}"
    chatgpt_answer = gpt_engine.generate(query)
    standard_dict_with_answer[ix]['prediction'] = chatgpt_answer

with open('benchmark_output/chatgpt/2-7.json', 'w') as f1:
    json.dump(standard_dict_with_answer, f1, indent=4, ensure_ascii=False)
# Out:
# 70it [03:23,  2.90s/it]

# %% [markdown]
# ### 2-9

# %%
df = pd.read_excel('dataset/summary benchmark.xlsx', sheet_name= '2-9 test')

# %%
standard_dict = list(df.T.to_dict().values())
for ix in range(len(standard_dict)):
    for key, value in standard_dict[ix].items():
        standard_dict[ix][key] = value.strip().rstrip()

standard_dict
# Out:
# [{'instruction': 'Dưới đây là một đoạn văn bản pháp lý, vui lòng xác định các sự kiện mà đoạn văn này đã nêu ra, bao gồm: thanh toán, lừa dối, khám xét, yêu cầu, bán ra, mua vào, thu lợi, bắt giữ, giám định, đồng ý, khai báo, đề nghị, liên lạc, thuê, bị thương, giả mạo, mại dâm, xâm hại thân thể, bồi thường, hoàn trả. Vui lòng đưa ra các sự kiện đã kích hoạt, ngăn cách bằng dấu chấm phẩy, ví dụ: thanh toán, bán ra. Vui lòng trả lời chính xác theo định dạng này. Dưới đây là một ví dụ:\nCâu hỏi: Theo giám định pháp y, nạn nhân XX bị gãy xương mũi hai bên, thuộc thương tích nhẹ cấp độ hai\nTrả lời: bị thương\nVui lòng trả lời:',
#   'question': 'Đến tháng 5/2019, T có nhắn tin rủ Q đến thị trấn Q để hẹn hò và sau đó hai người thực hiện hành vi quan hệ tình dục với nhau tại một nhà nghỉ trên địa bàn thị trấn Q, Q, thời điểm này T trên 20 tuổi, còn Q khoảng 15 tuổi 7 tháng',
#   'answer': 'xâm hại thân thể'},
# ...

# %%
with open('benchmark_v2/2-9.json', 'w') as f1:
    json.dump(standard_dict, f1, indent=4, ensure_ascii=False)

# %%
standard_dict_with_answer = standard_dict.copy()

for ix, element in tqdm(enumerate(standard_dict_with_answer)):
    query = f"{element['instruction']}\n{element['question']}"
    chatgpt_answer = gpt_engine.generate(query)
    standard_dict_with_answer[ix]['prediction'] = chatgpt_answer

with open('benchmark_output/chatgpt/2-9.json', 'w') as f1:
    json.dump(standard_dict_with_answer, f1, indent=4, ensure_ascii=False)
# Out:
# 70it [00:47,  1.49it/s]

# %% [markdown]
# ### 2-10

# %%
df = pd.read_excel('dataset/summary benchmark.xlsx', sheet_name= '2-10 test')

# %%
standard_dict = list(df.T.to_dict().values())
for ix in range(len(standard_dict)):
    for key, value in standard_dict[ix].items():
        standard_dict[ix][key] = value.strip().rstrip()

standard_dict
# Out:
# [{'instruction': 'Dưới đây là một đoạn văn bản pháp lý, vui lòng xác định những từ trong đoạn văn này đã kích hoạt một hoặc nhiều sự kiện sau, bao gồm:hôn nhân, tranh chấp, gây thương tích, trộm cắp. \nVui lòng trực tiếp đưa ra các từ kích hoạt sự kiện, ngăn cách bằng dấu chấm phẩy, ví dụ: “giám định pháp y; gãy xương”. Vui lòng trả lời chính xác theo định dạng này. Dưới đây là một ví dụ:\nCâu hỏi: Theo giám định pháp y, nạn nhân Hiếu bị gãy xương mũi hai bên, thuộc thương tích nhẹ cấp độ hai\nGiám định pháp y; gãy xương\nVui lòng trả lời:',
# ...

# %%
with open('benchmark_v2/2-10.json', 'w') as f1:
    json.dump(standard_dict, f1, indent=4, ensure_ascii=False)

# %%
standard_dict_with_answer = standard_dict.copy()

for ix, element in tqdm(enumerate(standard_dict_with_answer)):
    query = f"{element['instruction']}\n{element['question']}"
    chatgpt_answer = gpt_engine.generate(query)
    standard_dict_with_answer[ix]['prediction'] = chatgpt_answer

with open('benchmark_output/chatgpt/2-10.json', 'w') as f1:
    json.dump(standard_dict_with_answer, f1, indent=4, ensure_ascii=False)
# Out:
# 70it [01:02,  1.11it/s]

# %% [markdown]
# ### 3-1

# %%
df = pd.read_excel('dataset/summary benchmark.xlsx', sheet_name= '3-1 test')

# %%
standard_dict = list(df.T.to_dict().values())
for ix in range(len(standard_dict)):
    for key, value in standard_dict[ix].items():
        standard_dict[ix][key] = value.strip().rstrip()

standard_dict
# Out:
# [{'instruction': 'Các quy định của luật hình sự liên quan được đưa ra dựa trên các sự kiện và cáo buộc sau đây. Chỉ cần cho biết số điều luật trong bộ luật hình sự .\nCâu trả lời được format như sau: Điều xx Bộ luật hình sự\nVí dụ : Điều 128 Bộ luật hình sự, Điều 341 Bộ luật hình sự',
#   'question': 'Ngày 11/12/2021, tại quán "Cô Chủ Nhỏ" ở huyện Củ Chi, Thành phố Hồ Chí Minh, Nguyễn Trung T1 đã xảy ra mâu thuẫn với anh Trần Thanh P trong tiệc sinh nhật. Sau khi bị anh P kẹp cổ đánh, T1 gọi điện báo cho anh trai Nguyễn Trung C, nhờ mang hung khí đến. Nguyễn Trung C cùng Trần Ngọc T2 đã mang 2 cây rựa đến hiện trường.\n\nNguyễn Trung T1 và Nguyễn Trung C lần lượt sử dụng cây rựa chém anh P, gây tổn thương vùng đầu và tay với tỷ lệ thương tích 25%. Sau khi gây án, cả ba bị cáo bỏ trốn và sau đó bị bắt giữ.\n\nCáo buộc:\nCả ba bị cáo Nguyễn Trung T1, Nguyễn Trung C, và Trần Ngọc T2 bị truy tố tội "Giết người" với tình tiết tăng nặng là có tính chất côn đồ.',
# ...

# %%
with open('benchmark_v2/3-1.json', 'w') as f1:
    json.dump(standard_dict, f1, indent=4, ensure_ascii=False)

# %%
standard_dict_with_answer = standard_dict.copy()

for ix, element in tqdm(enumerate(standard_dict_with_answer)):
    query = f"{element['instruction']}\n{element['question']}"
    chatgpt_answer = gpt_engine.generate(query)
    standard_dict_with_answer[ix]['prediction'] = chatgpt_answer

with open('benchmark_output/chatgpt/3-1.json', 'w') as f1:
    json.dump(standard_dict_with_answer, f1, indent=4, ensure_ascii=False)
# Out:
# 0it [00:00, ?it/s]
# 70it [00:56,  1.24it/s]

# %% [markdown]
# ### 3-2

# %%
df = pd.read_excel('dataset/summary benchmark.xlsx', sheet_name= '3-2 test')

# %%
standard_dict = list(df.T.to_dict().values())
for ix in range(len(standard_dict)):
    for key, value in standard_dict[ix].items():
        standard_dict[ix][key] = value.strip().rstrip()

standard_dict
# Out:
# [{'instruction': 'Vui lòng cung cấp cơ sở pháp lý dựa trên các tình huống và câu hỏi cụ thể, chỉ trình bày các điều khoản pháp lý có liên quan. Mỗi tình huống phải được liên kết với một điều khoản pháp lý duy nhất.',
#   'question': 'Một người đàn ông đã đánh cắp một chiếc xe máy \nđã bị bắt giữ vì tội trộm cắp tài sản của người khác. \nTài sản bị trộm cắp có giá trị là 5 triệu đồng. Người \nđàn ông này đã từng bị kết án về tội trộm cắp tài \nsản trước đây. Theo quy định pháp lý nào, người \nđàn ông này sẽ bị xử lý hình sự về tội trộm cắp \ntài sản?',
#   'answer': 'Theo Điều 173 của Bộ luật Hình sự Việt Nam, người đàn ông này sẽ bị xử lý hình sự về tội trộm cắp tài sản theo quy định tại khoản 1, Điều 173.'},
#  {'instruction': 'Vui lòng cung cấp cơ sở pháp lý dựa trên các tình huống và câu hỏi cụ thể, chỉ trình bày các điều khoản pháp lý có liên quan. Mỗi tình huống phải được liên kết với một điều khoản pháp lý duy nhất.',
# ...

# %%
with open('benchmark_v2/3-2.json', 'w') as f1:
    json.dump(standard_dict, f1, indent=4, ensure_ascii=False)

# %%
standard_dict_with_answer = standard_dict.copy()

for ix, element in tqdm(enumerate(standard_dict_with_answer)):
    query = f"{element['instruction']}\n{element['question']}"
    chatgpt_answer = gpt_engine.generate(query)
    standard_dict_with_answer[ix]['prediction'] = chatgpt_answer

with open('benchmark_output/chatgpt/3-2.json', 'w') as f1:
    json.dump(standard_dict_with_answer, f1, indent=4, ensure_ascii=False)
# Out:
# 70it [03:33,  3.05s/it]

# %% [markdown]
# ### 3-3

# %%
df = pd.read_excel('dataset/summary benchmark.xlsx', sheet_name= '3-3 test')

# %%
standard_dict = list(df.T.to_dict().values())
for ix in range(len(standard_dict)):
    for key, value in standard_dict[ix].items():
        standard_dict[ix][key] = value.strip().rstrip()

standard_dict
# Out:
# [{'instruction': 'Vui lòng mô phỏng một thẩm phán \nvà cung cấp cáo buộc dựa trên các \nsự kiện sau. Chỉ cần tên của cáo buộc. \nVí dụ: [Tội danh:] Trộm cắp; Gian lận. \nVui lòng tuân thủ nghiêm ngặt định dạng này trong câu trả lời của bạn',
#   'question': 'Vào khoảng 7 giờ ngày 07/3/2024, Lò Tuấn L mang theo 300.000 đồng để tìm mua heroin tại bản Ông Lý, xã Chiềng Khừa, huyện Mộc Châu. Sau khi mua được 0,16 gam heroin từ một người đàn ông lạ mặt, L bị tổ công tác Công an huyện Yên Châu phát hiện và bắt quả tang khi về đến bản Tà Làng Trung, xã Tú Nang, huyện Yên Châu',
#   'answer': '[Tội danh:] Tàng trữ trái phép chất ma túy'},
#  {'instruction': 'Vui lòng mô phỏng một thẩm phán \nvà cung cấp cáo buộc dựa trên các \nsự kiện sau. Chỉ cần tên của cáo buộc. \nVí dụ: [Tội danh:] Trộm cắp; Gian lận. \nVui lòng tuân thủ nghiêm ngặt định dạng này trong câu trả lời của bạn',
# ...

# %%
with open('benchmark_v2/3-3.json', 'w') as f1:
    json.dump(standard_dict, f1, indent=4, ensure_ascii=False)

# %%
standard_dict_with_answer = standard_dict.copy()

for ix, element in tqdm(enumerate(standard_dict_with_answer)):
    query = f"{element['instruction']}\n{element['question']}"
    chatgpt_answer = gpt_engine.generate(query)
    standard_dict_with_answer[ix]['prediction'] = chatgpt_answer

with open('benchmark_output/chatgpt/3-3.json', 'w') as f1:
    json.dump(standard_dict_with_answer, f1, indent=4, ensure_ascii=False)
# Out:
# 70it [01:01,  1.14it/s]

# %% [markdown]
# ### 3-4

# %%
df = pd.read_excel('dataset/summary benchmark.xlsx', sheet_name= '3-4 test')

# %%
standard_dict = list(df.T.to_dict().values())
for ix in range(len(standard_dict)):
    for key, value in standard_dict[ix].items():
        standard_dict[ix][key] = value.strip().rstrip()

standard_dict
# Out:
# [{'instruction': 'Dựa trên các sự kiện, cáo buộc và điều khoản sau đây của bộ luật hình sự, hãy dự đoán thời hạn của bản án. Chỉ cung cấp thời hạn của bản án. Ví dụ: [Bản án] 12 tháng',
#   'question': 'Sự kiện: Vào ngày 10 tháng 5 năm 2018, tại khu vực đường phố ở thành phố Hà Nội, Biện Xuân T  đã thực hiện hành vi mua bán trái phép chất ma túy. Cụ thể, hắn đã bán 2 gói heroin có trọng lượng 10,2 gam cho một người đàn ông tên là Nguyễn Văn H. Quá trình mua bán diễn ra tại một quán cà phê ở gần đó. Sau khi nhận tiền, T  đã bị lực lượng công an bắt giữ. Tại thời điểm bị bắt, hắn đã thừa nhận hành vi mua bán trái phép chất ma túy và khai nhận đã bán heroin cho nhiều người khác trước đó.\n\nTội danh: Mua bán trái phép chất ma túy.\n\nĐiều luật: Điểm e, khoản 3 Điều 194 Bộ luật Hình sự.',
#   'answer': '[Bản án] 18 năm tù.'},
# ...

# %%
with open('benchmark_v2/3-4.json', 'w') as f1:
    json.dump(standard_dict, f1, indent=4, ensure_ascii=False)

# %%
standard_dict_with_answer = standard_dict.copy()

for ix, element in tqdm(enumerate(standard_dict_with_answer)):
    query = f"{element['instruction']}\n{element['question']}"
    chatgpt_answer = gpt_engine.generate(query)
    standard_dict_with_answer[ix]['prediction'] = chatgpt_answer

with open('benchmark_output/chatgpt/3-4.json', 'w') as f1:
    json.dump(standard_dict_with_answer, f1, indent=4, ensure_ascii=False)
# Out:
# 70it [00:59,  1.17it/s]

# %% [markdown]
# ### 3-5

# %%
df = pd.read_excel('dataset/summary benchmark.xlsx', sheet_name= '3-5 test')

# %%
standard_dict = list(df.T.to_dict().values())
for ix in range(len(standard_dict)):
    for key, value in standard_dict[ix].items():
        standard_dict[ix][key] = value.strip().rstrip()

standard_dict
# Out:
# [{'instruction': 'Vui lòng sử dụng kiến thức pháp lý của bạn để phân tích các trường hợp sau, chọn một câu trả lời đúng từ A, B, C, D và ghi vào giữa [câu trả lời đúng] và <eoa>. Ví dụ: [câu trả lời đúng] A<eoa>. Vui lòng trả lời theo đúng định dạng này. Sau đây là một ví dụ:\\nTrường mẫu giáo phải chịu trách nhiệm gì đối với thương tích cá nhân do người không có năng lực hành vi dân sự gây ra trong trường mẫu giáo? A: Trách nhiệm không lỗi; B: Trách nhiệm lỗi được cho là; C: Trách nhiệm công bằng; D: Trách nhiệm lỗi chung.\\n[Câu trả lời đúng] B\\nVui lòng trả lời:',
# ...

# %%
with open('benchmark_v2/3-5.json', 'w') as f1:
    json.dump(standard_dict, f1, indent=4, ensure_ascii=False)

# %%
standard_dict_with_answer = standard_dict.copy()

for ix, element in tqdm(enumerate(standard_dict_with_answer)):
    query = f"{element['instruction']}\n{element['question']}"
    chatgpt_answer = gpt_engine.generate(query)
    standard_dict_with_answer[ix]['prediction'] = chatgpt_answer

with open('benchmark_output/chatgpt/3-5.json', 'w') as f1:
    json.dump(standard_dict_with_answer, f1, indent=4, ensure_ascii=False)
# Out:
# 70it [00:53,  1.32it/s]

# %% [markdown]
# ### 3-6

# %%
df = pd.read_excel('dataset/summary benchmark.xlsx', sheet_name= '3-6 test')

# %%
df.head()
# Out:
#                                          instruction  \
# 0  Bạn là một chuyên gia về pháp luật Việt Nam vớ...
# 1  Bạn là một chuyên gia về pháp luật Việt Nam vớ...
# 2  Bạn là một chuyên gia về pháp luật Việt Nam vớ...
# 3  Bạn là một chuyên gia về pháp luật Việt Nam vớ...
# 4  Bạn là một chuyên gia về pháp luật Việt Nam vớ...
#
#                                             question  \
# 0  Nghĩa vụ nộp án phí sơ thẩm trong tố tụng dân ...
# 1  Người nhận thừa kế có phải trả nợ thay cho ngư...
# 2  Bố mẹ tôi có ý định cho riêng chị gái tôi (đã ...
# 3  Hồ sơ quản lý tạm giữ gồm những gì? Xin chào c...
# 4  Tôi muốn hỏi là trường hợp người đứng t...
#
#                                               answer
# 0  Nghĩa vụ nộp án phí sơ thẩm trong tố tụng dân ...
# 1  Căn cứ theo Điều 615 Bộ luật Dân sự 2015 quy đ...
# 2  Căn cứ vào Luật hôn nhân và gia đình năm 2014 ...
# 3  Việc tạm giữ là một biện pháp ngăn chặn được t...
# 4  Như bạn đã biết, theo quy định của pháp luật, ...

# %%
standard_dict = list(df.T.to_dict().values())
for ix in range(len(standard_dict)):
    for key, value in standard_dict[ix].items():
        if type(value)!= float: print(key, value, ix)
        standard_dict[ix][key] = value.strip().rstrip()

standard_dict
# Out:
# instruction Bạn là một chuyên gia về pháp luật Việt Nam với nhiều năm kinh nghiệm. Nhiệm vụ của bạn là cung cấp các câu trả lời tư vấn chính xác, lập luận chặt chẽ, và xác thực. Hãy giúp mọi người giải đáp rõ ràng cho câu hỏi dưới đây:  0
# question Nghĩa vụ nộp án phí sơ thẩm trong tố tụng dân sự theo Bộ luật tố tụng dân sự 2004 được quy định như thế nào? Xin chào Ban biên tập, tôi là Ngọc Hải hiện đang sống và làm việc tại Long An. Tôi hiện đang tìm hiểu về pháp luật tố tụng dân sự qua các năm. Vậy Ban biên tập cho tôi hỏi nghĩa vụ nộp án phí sơ thẩm trong tố tụng dân sự theo Bộ luật tố tụng dân sự 2004 được quy định như thế nào? Mong Ban biên tập giải đáp giúp tôi trong thời gian sớm nhất. Chân thành cảm ơn và chúc sức khỏe Ban biên tập!  0
# ...

# %%
with open('benchmark_v2/3-6.json', 'w') as f1:
    json.dump(standard_dict, f1, indent=4, ensure_ascii=False)

# %%
standard_dict_with_answer = standard_dict.copy()

for ix, element in tqdm(enumerate(standard_dict_with_answer)):
    query = f"{element['instruction']}\n{element['question']}"
    chatgpt_answer = gpt_engine.generate(query)
    standard_dict_with_answer[ix]['prediction'] = chatgpt_answer

with open('benchmark_output/chatgpt/3-6.json', 'w') as f1:
    json.dump(standard_dict_with_answer, f1, indent=4, ensure_ascii=False)
# Out:
# 68it [07:22,  6.51s/it]
